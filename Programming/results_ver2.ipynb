# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
plt.rcParams.update({'font.family':'Times New Roman'})
plt.rcParams['figure.dpi'] = 800

# %%
df = pd.read_csv(r'H:\stOOrz-Mathematical-Modelling-Group\IMMC_2022_Greater_China_Oral_Defense\Programming\resultss.csv')
df.rename(columns={'type':'Boarding Type','time': 'Time', 'dissatisfaction': 'Dissatisfaction'}, inplace=True)
time_df = df
satis_df = df
df
# Out:
#                        Boarding Type  Time  Dissatisfaction
# 0                      front to back  5029           938.82
# 1                      back to front  4092           854.01
# 2         random window middle aisle  4347          1207.81
# 3  back-to-front window middle aisle  4120          1482.14
# 4  front-to-back window middle aisle  4398          1501.17
# 5                             random  4409          1222.25
# 6                    steffen perfect  3770          1415.09
# 7                steffen sub-perfect  3359          1383.59
# 8              five-section boarding  4262              NaN

# %%
# df.drop(['Dissatisfaction'],axis=1, inplace=True)
df.sort_values('Time', inplace=True)
df.reset_index(drop=True)
df
# Out:
#                        Boarding Type  Time  Dissatisfaction
# 7                steffen sub-perfect  3359          1383.59
# 6                    steffen perfect  3770          1415.09
# 1                      back to front  4092           854.01
# 3  back-to-front window middle aisle  4120          1482.14
# 8              five-section boarding  4262              NaN
# 2         random window middle aisle  4347          1207.81
# 4  front-to-back window middle aisle  4398          1501.17
# 5                             random  4409          1222.25
# 0                      front to back  5029           938.82

# %%
time = df['Time'].to_list()
ave_time = np.average(time)
ave_time
# Out:
# 4198.444444444444

# %%
df = df.append({'Boarding Type': 'average', 'Time':ave_time},ignore_index=True)
df
# Out:
#                        Boarding Type         Time  Dissatisfaction
# 0                steffen sub-perfect  3359.000000          1383.59
# 1                    steffen perfect  3770.000000          1415.09
# 2                      back to front  4092.000000           854.01
# 3  back-to-front window middle aisle  4120.000000          1482.14
# 4              five-section boarding  4262.000000              NaN
# 5         random window middle aisle  4347.000000          1207.81
# 6  front-to-back window middle aisle  4398.000000          1501.17
# 7                             random  4409.000000          1222.25
# 8                      front to back  5029.000000           938.82
# 9                            average  4198.444444              NaN

# %%
df.sort_values('Time', inplace=True)
df['Dissatisfaction']
# Out:
# 0    1383.59
# 1    1415.09
# 2     854.01
# 3    1482.14
# 9        NaN
# 4        NaN
# 5    1207.81
# 6    1501.17
# 7    1222.25
# 8     938.82
# Name: Dissatisfaction, dtype: float64

# %%
df['Dissatisfaction'][4]=1322.91
lst = df['Dissatisfaction'].to_list()
df['Dissatisfaction'][9] = np.average(lst)
lst
# Out:
# <ipython-input-130-4afb652a80ae>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Dissatisfaction'][4]=1322.91
# <ipython-input-130-4afb652a80ae>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Dissatisfaction'][9] = np.average(lst)
# [1383.59,
#  1415.09,
#  854.01,
#  1482.14,
#  nan,
#  1322.91,
#  1207.81,
#  1501.17,
#  1222.25,
#  938.82]

# %%
lst.pop(4)
lst
df['Dissatisfaction'][9] = np.average(lst)
# Out:
# <ipython-input-131-892729b69a4e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Dissatisfaction'][9] = np.average(lst)

# %%
df
# Out:
#                        Boarding Type         Time  Dissatisfaction
# 0                steffen sub-perfect  3359.000000      1383.590000
# 1                    steffen perfect  3770.000000      1415.090000
# 2                      back to front  4092.000000       854.010000
# 3  back-to-front window middle aisle  4120.000000      1482.140000
# 9                            average  4198.444444      1258.643333
# 4              five-section boarding  4262.000000      1322.910000
# 5         random window middle aisle  4347.000000      1207.810000
# 6  front-to-back window middle aisle  4398.000000      1501.170000
# 7                             random  4409.000000      1222.250000
# 8                      front to back  5029.000000       938.820000

# %%
ax_time = df.plot.barh(x='Boarding Type',y='Time')

# %%
df
# Out:
#                        Boarding Type         Time  Dissatisfaction
# 0                steffen sub-perfect  3359.000000      1383.590000
# 1                    steffen perfect  3770.000000      1415.090000
# 2                      back to front  4092.000000       854.010000
# 3  back-to-front window middle aisle  4120.000000      1482.140000
# 9                            average  4198.444444      1258.643333
# 4              five-section boarding  4262.000000      1322.910000
# 5         random window middle aisle  4347.000000      1207.810000
# 6  front-to-back window middle aisle  4398.000000      1501.170000
# 7                             random  4409.000000      1222.250000
# 8                      front to back  5029.000000       938.820000

# %%
colors1=['b','b','b','b','g','b','b','b','b','b']
colors2=['r','r','r','r','orange','r','r','r','r','r']

# %%
# ax_time = df.plot.barh(x='Boarding Type',y=['Time', 'Dissatisfaction'],title='Boarding time', color={'Time':colors1, 'Dissatisfaction':colors2},figsize=(10,5))
# ax_time.legend(loc=4)
# host = host_subplot(111, axes_class=AA.Axes)
# plt.subplots_adjust(right=0.75)
# ax_time1 = host.twinx()
fig, ax_time1 = plt.subplots()

ax_time1 = df.plot.barh(x='Boarding Type', y='Time', color=colors1)
ax_time1.tick_params(axis='x', labelcolor='b')
for i in range(10):
    ax_time1.text(items1[i], i,int(items1[i]), ha='left', va='top',color=colors1[i])
ax_time1.set_xlabel('Total Time Steps')
    
ax_time2 = ax_time1.twiny()
ax_time2.tick_params(axis='x', labelcolor='r')
ax_time2 = df.plot.barh(x='Boarding Type', y='Dissatisfaction', color=colors2)
for i in range(10):
    ax_time2.text(items2[i], i,int(items2[i]), ha='left', va='bottom',color=colors2[i])
ax_time2.set_xlabel(r'$\alpha_{\mathrm{satisfy}}$')

# ax_time.text(,6,'hello', ha='center', va='bottom')
items1 = df['Time'].to_list()
items2 = df['Dissatisfaction'].to_list()


data1 = df['Time'].to_list()
data2 = df['Dissatisfaction'].to_list()
index = df['Boarding Type'].to_list()

# %%
data1
# Out:
# [3359.0,
#  3770.0,
#  4092.0,
#  4120.0,
#  4198.444444444444,
#  4262.0,
#  4347.0,
#  4398.0,
#  4409.0,
#  5029.0]

# %%
data2
# Out:
# [1383.59,
#  1415.09,
#  854.01,
#  1482.14,
#  1258.6433333333334,
#  1322.91,
#  1207.81,
#  1501.17,
#  1222.25,
#  938.82]

# %%
index
# Out:
# ['steffen sub-perfect',
#  'steffen perfect',
#  'back to front',
#  'back-to-front window middle aisle',
#  'average',
#  'five-section boarding',
#  'random window middle aisle',
#  'front-to-back window middle aisle',
#  'random',
#  'front to back']

# %%
from matplotlib.pyplot import figure

fig, ax1 = plt.subplots()

# ax1 = figure(figsize=(20,10), dpi=80)

TIMES = 3
WIDTH = 0.7
ticks = index
bar1 = range(0, len(index)*TIMES, TIMES)
bar2 = [i+WIDTH for i in bar1]

ax1.set_ylabel('Boarding Type')
ax1.set_xlabel('Time Steps', color='b')
ax1.barh(bar1,  data1,WIDTH, color=colors1)
for i in range(10):
    ax1.text(items1[i], bar1[i],int(items1[i]), ha='left', va='top',color=colors1[i],size=8)
ax1.tick_params(axis='x', labelcolor='b')
ax1.legend(['Dissatisfaction'], loc=(1.05,0.1))
ax1.set_xlim(0,6000)
ax1.set_yticks([])

ax2 = ax1.twiny()
ax2.set_xlabel(r'$\alpha_{\mathrm{satisfy}}$', color='r')
ax2.barh(bar2,  data2,WIDTH, color=colors2)
ax2.legend(['Time Steps'], loc=(1.05,0.2))
ax2.set_xlim(0,2000)
for i in range(10):
    ax2.text(items2[i], bar2[i],int(items2[i]), ha='left', va='bottom',color=colors2[i],size=8)
ax2.tick_params(axis='x', labelcolor='r')

# %%
ax1
# Out:
# <AxesSubplot:xlabel='Time Steps', ylabel='Boarding Type'>

# %%
bar1
# Out:
# range(0, 20, 2)

# %%
import numpy as np
import matplotlib.pyplot as plt

# Create some mock data
t = np.arange(0.01, 10.0, 0.01)
data1 = np.exp(t)
data2 = np.sin(2 * np.pi * t)

fig, ax1 = plt.subplots()

color = 'tab:red'
ax1.set_xlabel('time (s)')
ax1.set_ylabel('exp', color=color)
ax1.plot(t, data1, color=color)
ax1.tick_params(axis='y', labelcolor=color)
ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

color = 'tab:blue'
ax2.set_ylabel('sin', color=color)  # we already handled the x-label with ax1
ax2.plot(t, data2, color=color)
ax2.tick_params(axis='y', labelcolor=color)

fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.show()
